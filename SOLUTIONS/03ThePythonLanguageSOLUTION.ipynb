# %% [markdown]
# # EXERCISE SHEET

# %% [markdown]
# Generate a Text Cell below this one and enter your name as plain text.

# %% [markdown]
# Juan Klopper

# %% [markdown]
# Generate a Text Cell below this one and add the title MY FIRST EXERCISE SHEET as a second level title (two hashtags).

# %% [markdown]
# ## MY FIRST EXERCISE SHEET

# %% [markdown]
# Look at the markdown code in the `03ThePythonLanguageForDataScience.ipynb` Colab notebook and create a table with two column, a header row, and three rows of data in a new Text Cell below this one. Any values will do.

# %% [markdown]
# | Height | Weight |
# | :------| :------|
# | 196    | 92     |
# | 170    | 56     |
# | 179    | 55     |

# %% [markdown]
# Generate a Text Cell below this one and write any sentence. Format one word to display in bold type and one in italics.

# %% [markdown]
# This word is __bold__ and this word is _italic_.

# %% [markdown]
# Do the following calculation in the code cell below.
#
# $$ 3 + 4 - 2 $$

# %%
# Enter your solution here
3 + 4 - 2
# Out:
# 5

# %% [markdown]
# Do the following calculation in the code cell below.
#
# $$ \frac{4 + 4 \times 2}{3} $$

# %%
# Enter your solution here
(4 + 4 * 2) / 3
# Out:
# 4.0

# %% [markdown]
# Calculate the remainder of the following division in the code cell below.
#
# $$ \frac{100}{3} $$

# %%
# Enter your solution here
100 % 3
# Out:
# 1

# %% [markdown]
# Import the math package in the code cell below.

# %%
# Enter your solution here
import math

# %% [markdown]
# Use the math package to print the value of $\pi$ to the screen.

# %%
# Enter your solution here
math.pi
# Out:
# 3.141592653589793

# %% [markdown]
# If the equation for the circumference of a circle is $\pi r^{2}$ (where $r$ is the radius of a circle), calculate the circumferene of a circle with a radius, $r=2$ in the code cell below.

# %%
# Enter your solution here
math.pi * 2**2
# Out:
# 12.566370614359172

# %% [markdown]
# Calculate the square root of $53824$.

# %%
# Enter your solution here
math.sqrt(53824)
# Out:
# 232.0

# %% [markdown]
# Assign the sentence _I love Data Science_ to the computer variable of your choice and print the result to the screen.

# %%
# Enter your solution here
my_passion = 'I love Data Science'
my_passion
# Out:
# 'I love Data Science'

# %% [markdown]
# Create a Python dictionary with the keys and values shown in the table below and assign the dictionary to a computer variable of your choice.
#
# | Keys               | Value |
# | :------------------| :-----|
# | Mean               | 12.8  |
# | Standard deviation | 3.4   |
# | IQR                | 5     |

# %%
# Enter your solution here
my_dict = {'Mean': 12.8, 'Standard deviation': 3.4, 'IQR': 5}

# %% [markdown]
# Print all the values of the dictionary to the screen.

# %%
# Enter your solution here
my_dict.values()
# Out:
# dict_values([12.8, 3.4, 5])

# %% [markdown]
# Why can't you use the computer variable name `dict` for your dictionary above?

# %% [markdown]
# The reason is:

# %% [markdown]
# Set up a loop counter, initiated to $0$. Use a `while` loop to print the square of each integer up to $5$ to the screen.

# %%
# Enter your solution here
i = 0
while i < 6:
  print(i**2)
  i = i + 1
# Out:
# 0
# 1
# 4
# 9
# 16
# 25

# %% [markdown]
# Import the numpy package using the namespace abbreviation `np`.

# %%
# Enter your solution here
import numpy as np

# %% [markdown]
# The code below generates $300$ random numbers and assigns the resultant array to the computer variable `numbers`.

# %%
numbers = np.random.randint(10, high=20, size=300)

# %% [markdown]
# Print the last element of the array to the screen.

# %%
# Enter your solution here
numbers[-1]
# Out:
# 11

# %% [markdown]
# Print the first five element to the screen.

# %%
# Enter your solution here
numbers[:5]
# Out:
# array([13, 16, 18, 18, 18])

# %% [markdown]
# If the geometric mean of a set of five numbers is the $5^{\text{th}}$ root of their product (multiplication), calculate the geometric mean of the numbers $3,4,5,6$, and $7$. Clue: Do an online search for geometric mean and Python. Alternatively, you can do the calculation directly.

# %%
# Enter your solution here
from scipy.stats.mstats import gmean
gmean([3, 4, 5, 6, 7])
# Out:
# 4.789388953186989

# %%
# Enter your solution here
(3 * 4 * 5 * 6 * 7)**(1/5)
# Out:
# 4.789388953186989

# %% [markdown]
# Is this value larger than the arithmetic mean, which is simply the addition of all the numbers divided by how many there are?

# %%
# Enter your solution here
gmean([3, 4, 5, 6, 7]) > np.mean([3, 4, 5, 6, 7])
# Out:
# False

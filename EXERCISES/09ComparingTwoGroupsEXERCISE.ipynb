# %% [markdown]
# Run the code cell below.

# %%
# %load_ext google.colab.data_table

# %% [markdown]
# Import the numpy and pandas package using the namespace abbreviations `np` and `pd`.

# %%
# Enter your solution here

# %% [markdown]
# Import the stats module from scipy.

# %%
# Enter your solution here

# %% [markdown]
# Run the code cell below to import the express module of the plotly package and to set the default theme for plots.

# %%
import plotly.express as px
import plotly.io as pio

pio.templates.default = 'plotly_white'

# %% [markdown]
# Run the code cell below to generate values for two variables.

# %%
np.random.seed(28)
height = np.random.randint(150, high=200, size=200)
group = np.random.choice(['I', 'II'], size=200, p=[0.6, 0.4])

# %% [markdown]
# Run the code cell below to add these values to a dataframe object. Consider this the test results of a study that you are conducting.

# %%
df = pd.DataFrame({
    'Height':height,
    'Group':group
})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-c743fb307f66> in <module>()
# ----> 1 df = pd.DataFrame({
#       2     'Height':height,
#       3     'Group':group
#       4 })
#
# NameError: name 'pd' is not defined

# %% [markdown]
# Calculate the frequency of the sample space elements in the `Group` column (size of each sample in the study). Hint: First create a pandas series object (using either dot notation or square bracket notation, i.e. `df.Group` or `df['Group']`) and then add the `value_counts` method.

# %%
# Enter your solution here
# Out:
# I     127
# II     73
# Name: Group, dtype: int64

# %% [markdown]
# Show the results as proprotions.

# %%
# Enter your solution here
# Out:
# I     0.635
# II    0.365
# Name: Group, dtype: float64

# %% [markdown]
# Calculate summary statistics for the height of the subjects in your study. Hint: First create a pandas series object (using either dot notation or square bracket notation) and then add the `describe` method.

# %%
# Enter your solution here
# Out:
# count    200.000000
# mean     173.690000
# std       14.268562
# min      150.000000
# 25%      161.000000
# 50%      174.000000
# 75%      187.000000
# max      199.000000
# Name: Height, dtype: float64

# %% [markdown]
# Calculate comparitive descriptive statistics for the `Height` variable based on the sample space elements of the `Group`. Hint: Use the `groupby` method.

# %%
# Enter your solution here
# Out:
#        count        mean        std    min    25%    50%    75%    max
# Group
# I      127.0  173.188976  14.043997  150.0  160.0  174.0  185.5  198.0
# II      73.0  174.561644  14.708261  150.0  162.0  173.0  188.0  199.0

# %% [markdown]
# The test statistic of this study is the difference in mean height between the two groups. Run the code below that calculate the difference in mean heights.

# %%
stat = np.mean(df.loc[df.Group == 'I'].Height) - np.mean(df.loc[df.Group == 'II'].Height)
stat
# Out:
# -1.372667457663681

# %% [markdown]
# Under the null hypothesis there is no difference in mean height between the two groups. The code below reassigns each subejct to a random group and generates $1000$ mean differences.

# %%
mean_stat = []
height_copy = height.copy()

for i in range(1000):
  np.random.shuffle(height_copy)
  mean_stat.append(np.mean(height_copy[0:127]) - np.mean(height_copy[128:200]))

# %% [markdown]
# Run the code cell below to show a histogram of all the test statistics.

# %%
px.histogram(x=mean_stat,
             title='Test statistic sampling distribution',
             labels={'x':'Differences in means'})
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="e9899c6e-8d11-494b-af1f-98014f2218b2" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("e9899c6e-8d11-494b-af1f-98014f2218b2")) {
#                     Plotly.newPlot(
#                         'e9899c6e-8d11-494b-af1f-98014f2218b2',
#                         [{"alignmentgroup": "True", "bingroup": "x", "hoverlabel": {"namelength": 0}, "hovertemplate": "Differences in means=%{x}<br>count=%{y}", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "type": "histogram", "x": [1.46905074365705, -0.3849518810148709, 0.23228346456693316, 3.3781714785651786, 0.8880139982502158, -2.7566710411198585, 2.502077865266841, 1.242235345581804, -5.242672790901139, 0.14063867016622567, -1.2258311461067137, 1.1213910761154864, 2.1844925634295578, -2.1218285214348214, 1.49912510936133, 1.3602362204724443, -0.4423665791775875, -1.2836832895887937, 0.42257217847767947, 0.5522747156605305, -0.1511373578302937, 1.7931977252843296, 4.079286964129494, 1.9834864391951044, 0.3711723534558189, 1.3135389326334348, -0.5673665791775875, -1.8059930008749063, -1.4897200349956279, 0.37773403324584365, 0.5754593175853131, -0.6952099737532649, 3.4416010498687797, 0.545822397